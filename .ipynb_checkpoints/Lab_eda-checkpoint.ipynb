# %%
import pandas as pd
url = "/Users/alexkabanovsky/Downloads/amz_uk_price_prediction_dataset.csv"
df = pd.read_csv(url)
df
# Out:
#              uid        asin  \
# 0              1  B09B96TG33
# 1              2  B01HTH3C8S
# 2              3  B09B8YWXDF
# 3              4  B09B8T5VGV
# 4              5  B09WX6QD65
# ...          ...         ...
# 2443646  2828589  B0CHSD7P2Q
# 2443647  2828590  B0B7B8FNBQ
# 2443648  2828591  B0BD5FL5FB
# 2443649  2828592  B008OYLL4I
# 2443650  2828593  B08P3W9B3T
#
#                                                      title  stars  reviews  \
# 0        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 1        Anker Soundcore mini, Super-Portable Bluetooth...    4.7    98099
# 2        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 3        Echo Dot with clock (5th generation, 2022 rele...    4.7     7205
# 4        Introducing Echo Pop | Full sound compact Wi-F...    4.6     1881
# ...                                                    ...    ...      ...
# 2443646  Motorbike Armour, Motorbike Clothing, Cycling ...    0.0        0
# ...

# %%
frequency_table = df['category'].value_counts()
frequency_table
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
#                                            ...
# Alexa Built-In Devices                       107
# Motorbike Chassis                            107
# Plugs                                        107
# Smart Home Security & Lighting               104
# Smart Speakers                                54
# Name: count, Length: 296, dtype: int64

# %%
# the top 5 most listed product categories are Sports & Outdoors, Beauty, Handmade Clothing, Shoes & Accessories, Bath & Body and Birthday Gifts

# %%
filtered_frequency_table = df['category'].value_counts().iloc[1:].head(20)
filtered_frequency_table
# Out:
# category
# Beauty                                    19312
# Handmade Clothing, Shoes & Accessories    19229
# Bath & Body                               19092
# Birthday Gifts                            18978
# Manicure & Pedicure Products              18940
# Skin Care                                 18769
# Make-up                                   18756
# Hair Care                                 18735
# Fragrances                                18564
# Handmade Gifts                            18295
# Handmade Home Décor                       18146
# Luggage and travel gear                   18142
# Handmade Jewellery                        18044
# Handmade Artwork                          17878
# Women                                     17772
# Handmade Home & Kitchen Products          17435
# Handmade Kitchen & Dining                 17432
# Men                                       17417
# Baby                                      15050
# ...

# %%
proportion_table = (df['category'].value_counts(normalize=True) * 100).round(2).head(20)
proportion_table
# Out:
# category
# Sports & Outdoors                         34.22
# Beauty                                     0.79
# Handmade Clothing, Shoes & Accessories     0.79
# Bath & Body                                0.78
# Birthday Gifts                             0.78
# Manicure & Pedicure Products               0.78
# Skin Care                                  0.77
# Make-up                                    0.77
# Hair Care                                  0.77
# Fragrances                                 0.76
# Handmade Gifts                             0.75
# Handmade Home Décor                        0.74
# Luggage and travel gear                    0.74
# Handmade Jewellery                         0.74
# Handmade Artwork                           0.73
# Women                                      0.73
# Handmade Home & Kitchen Products           0.71
# Handmade Kitchen & Dining                  0.71
# Men                                        0.71
# ...

# %%
filtered_proportion_table = (df['category'].value_counts(normalize=True) * 100).round(2).iloc[1:].head(5)
filtered_proportion_table
# Out:
# category
# Beauty                                    0.79
# Handmade Clothing, Shoes & Accessories    0.79
# Bath & Body                               0.78
# Birthday Gifts                            0.78
# Manicure & Pedicure Products              0.78
# Name: proportion, dtype: float64

# %%
#Display the distribution of products across different categories using a bar chart - do it for a subset of top categories.
#For a subset of top categories, visualize their proportions using a pie chart. Does any category dominate the listings?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x=filtered_frequency_table.index, y=filtered_frequency_table.values, palette="Set3")
plt.xlabel('Categories')  # Set x-axis label
plt.ylabel('Frequency')   # Set y-axis label
plt.title('Barplot of Frequency Table of Top 20 Product Categories (excl. Sport & Outdoors)')  # Add a title
plt.xticks(rotation=90)  # Rotate x-axis labels if necessary
plt.show()
# Out:
# /var/folders/tk/l3rys1j13d714cd0mx1y2mn00000gn/T/ipykernel_85667/491522155.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=filtered_frequency_table.index, y=filtered_frequency_table.values, palette="Set3")

# %%
#Display the distribution of products across different categories using a bar chart - do it for a subset of top categories.
#For a subset of top categories, visualize their proportions using a pie chart. Does any category dominate the listings?

# %%
import matplotlib.pyplot as plt

# Step 1: Get value counts of the 'category' column
category_counts = proportion_table

# Step 2: Create the pie chart
plt.pie(category_counts.values, labels=category_counts.index, autopct='%1.1f%%', startangle=45)

# Step 3: Customize and show the chart
plt.title('Category Distribution')
plt.axis('equal')  # Ensures that the pie is drawn as a circle
plt.show()

# %%
category_counts = filtered_proportion_table

plt.pie(category_counts.values, labels=category_counts.index, autopct='%1.1f%%', startangle=45)
plt.title('Category Distribution excluding Sports & Outdoors')
plt.axis('equal') 
plt.show()

# %%
# measures of centrality
# Calculate the mean, median, and mode for the price of products.
# What's the average price point of products listed? How does this compare with the most common price point (mode)?

# %%
mean_price = df['price'].mean().round(2)
median_price = df['price'].median()
mode_price = df['price'].mode()[0]
mean_price, median_price, mode_price
# Out:
# (89.24, 19.09, 9.99)

# %%
# the mean is almost 10 times higher than the mode, the distribution is clearly positively skewed

# %%
#Determine the variance, standard deviation, range, and interquartile range for product price.
#How varied are the product prices? Are there any indicators of a significant spread in prices?

# %%
var = round(df['price'].var(), 2)
std_dev = round(df['price'].std(), 2)
var, std_dev
# Out:
# (119445.49, 345.61)

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
Q1, Q3, IQR
# Out:
# (9.99, 45.99, 36.0)

# %%
skewness_price = df['price'].skew().round(1)
kurtosis_price = df['price'].kurtosis().round(1)

skewness_price, kurtosis_price
# Out:
# (27.5, 4241.6)

# %%
# Is there a specific price range where most products fall? Plot a histogram to visualize the distribution of product prices.
#If its hard to read these diagrams, think why this is, and explain how it could be solved..
# Are there products that are priced significantly higher than the rest? 
#Use a box plot to showcase the spread and potential outliers in product pricing.

# %%
sns.histplot(df['price'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# Step 1: Plot the histogram
plt.hist(df['price'], bins=10, edgecolor='black')

# Step 2: Customize labels and title
plt.xlabel('Price')
plt.ylabel('Quantity')
plt.title('Histogram of prices')

# Step 3: Display the plot
plt.show()

# %%
pd.qcut (df['price'], q= 4, labels = ['very cheap', 'cheap', 'expensive', 'very expensive'])
# Out:
# 0               expensive
# 1               expensive
# 2               expensive
# 3               expensive
# 4                   cheap
#                 ...
# 2443646         expensive
# 2443647    very expensive
# 2443648    very expensive
# 2443649    very expensive
# 2443650    very expensive
# Name: price, Length: 2443651, dtype: category
# Categories (4, object): ['very cheap' < 'cheap' < 'expensive' < 'very expensive']

# %%
price_bin = pd.qcut (df['price'], q= 4)
sns.countplot(x=price_bin)
# Out:
# <Axes: xlabel='price', ylabel='count'>

# %%
#Calculate the mean, median, and mode for the rating of products.
#How do customers generally rate products? Is there a common trend?
#Determine the variance, standard deviation, and interquartile range for product rating.
#Are the ratings consistent, or is there a wide variation in customer feedback?
# Calculate the skewness and kurtosis for the rating column.
# Are the ratings normally distributed, or do they lean towards higher or lower values?

#Plot a histogram to visualize the distribution of product ratings. Is there a specific rating that is more common?

# %%
mean_rating = df['stars'].mean().round(2)
median_rating = df['stars'].median()
mode_rating = df['stars'].mode()[0]
mean_rating, median_rating, mode_rating
# Out:
# (2.15, 0.0, 0.0)

# %%
var_rating = round(df['stars'].var(), 2)
std_dev_rating = round(df['stars'].std(), 2)
var_rating, std_dev_rating
# Out:
# (4.82, 2.19)

# %%
Q1 = df['stars'].quantile(0.25)
Q3 = df['stars'].quantile(0.75)
IQR = Q3 - Q1
Q1, Q3, IQR
# Out:
# (0.0, 4.4, 4.4)

# %%
skewness_rating = df['stars'].skew().round(1)
kurtosis_rating = df['stars'].kurtosis().round(1)

skewness_rating, kurtosis_rating
# Out:
# (0.1, -1.9)
